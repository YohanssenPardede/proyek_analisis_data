# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Input Nama]
# - **Email:** [Input Email]
# - **ID Dicoding:** [Input Username]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1.   Bagaimana segmentasi pelanggan berdasarkan analisis RFM, dan segmen pelanggan mana yang paling berharga bagi bisnis?
# 2.   Apakah ada perbedaan kepuasan pelanggan (berdasarkan ulasan) di berbagai wilayah geografis, dan apakah waktu pengiriman memengaruhi kepuasan tersebut?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Load datasets into pandas DataFrames
customers_df = pd.read_csv('olist_customers_dataset.csv')
geolocation_df = pd.read_csv('olist_geolocation_dataset.csv')
order_items_df = pd.read_csv('olist_order_items_dataset.csv')
payments_df = pd.read_csv('olist_order_payments_dataset.csv')
reviews_df = pd.read_csv('olist_order_reviews_dataset.csv')
orders_df = pd.read_csv('olist_orders_dataset.csv')
products_df = pd.read_csv('olist_products_dataset.csv')
sellers_df = pd.read_csv('olist_sellers_dataset.csv')
product_category_translation_df = pd.read_csv('product_category_name_translation.csv')

# %%
# Display the first few rows of each dataset to verify successful loading
print("Customers Dataset")
print(customers_df.head(), "\n")
# Out:
# Customers Dataset
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
print("Geolocation Dataset")
print(geolocation_df.head(), "\n")
# Out:
# Geolocation Dataset
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
print("Order Items Dataset")
print(order_items_df.head(), "\n")
# Out:
# Order Items Dataset
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# ...

# %%
print("Payments Dataset")
print(payments_df.head(), "\n")
# Out:
# Payments Dataset
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
print("Reviews Dataset")
print(reviews_df.head(), "\n")
# Out:
# Reviews Dataset
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# ...

# %%
print("Orders Dataset")
print(orders_df.head(), "\n")
# Out:
# Orders Dataset
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
print("Products Dataset")
print(products_df.head(), "\n")
# Out:
# Products Dataset
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
print("Sellers Dataset")
print(sellers_df.head(), "\n")
# Out:
# Sellers Dataset
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
print("Product Category Name Translation Dataset")
print(product_category_translation_df.head(), "\n")
# Out:
# Product Category Name Translation Dataset
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
# Merge customers with orders
merged_df = pd.merge(orders_df, customers_df, on='customer_id', how='left')

# Merge order_items with products and sellers
merged_df = pd.merge(merged_df, order_items_df, on='order_id', how='left')
merged_df = pd.merge(merged_df, products_df, on='product_id', how='left')
merged_df = pd.merge(merged_df, sellers_df, on='seller_id', how='left')

# Merge orders with payments and reviews
merged_df = pd.merge(merged_df, payments_df, on='order_id', how='left')
merged_df = pd.merge(merged_df, reviews_df, on='order_id', how='left')

# Merge with geolocation data (customer side)
merged_df = pd.merge(merged_df, geolocation_df, left_on='customer_zip_code_prefix', right_on='zip_code_prefix', how='left')

# Merge with product category translation
merged_df = pd.merge(merged_df, product_category_translation_df, on='product_category_name', how='left')

# Display the merged dataframe
print(merged_df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12256\1399504902.py in <module>
#      12
#      13 # Merge with geolocation data (customer side)
# ---> 14 merged_df = pd.merge(merged_df, geolocation_df, left_on='customer_zip_code_prefix', right_on='zip_code_prefix', how='left')
#      15
#      16 # Merge with product category translation
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %%
# Check for missing values
missing_values = rfm_df.isnull().sum()

# Get data types and overall info
data_info = rfm_df.dtypes

# Check for duplicates
duplicate_rows = rfm_df.duplicated().sum()

# Summary statistics of the numerical columns
summary_statistics = rfm_df.describe()

# Display results
print("Missing Values:\n", missing_values)
print("\nData Types:\n", data_info)
print("\nNumber of Duplicate Rows:", duplicate_rows)
print("\nSummary Statistics:\n", summary_statistics)
# Out:
# Missing Values:
#  order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date     1194
# order_delivered_customer_date    2454
# order_estimated_delivery_date       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# price                               0
# dtype: int64
#
# Data Types:
#  order_id                          object
# customer_id                       object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# customer_unique_id                object
# ...

# %% [markdown]
# Berdasarkan hasil **assessing data**, berikut adalah temuan dan beberapa langkah yang dapat diambil untuk membersihkan data sebelum melanjutkan analisis RFM:
#
# Temuan Utama:
# 1. **Missing Values**:
#    - Kolom `order_approved_at` memiliki **15** nilai yang hilang.
#    - Kolom `order_delivered_carrier_date` memiliki **1194** nilai yang hilang.
#    - Kolom `order_delivered_customer_date` memiliki **2454** nilai yang hilang.
#    - Kolom lain seperti `order_purchase_timestamp`, `customer_zip_code_prefix`, dan `price` tidak memiliki missing values.
#
# 2. **Tipe Data**:
#    - Beberapa kolom yang berhubungan dengan waktu, seperti `order_approved_at`, `order_delivered_carrier_date`, dan `order_delivered_customer_date`, masih bertipe **object**. Kolom ini perlu diubah menjadi tipe datetime agar bisa digunakan dengan benar dalam analisis waktu.
#
# 3. **Duplikasi**:
#    - Ada **11380 baris duplikat** dalam data. Ini perlu diatasi dengan menghapus duplikasi untuk memastikan integritas data.
#
# 4. **Statistik Deskriptif**:
#    - Rata-rata nilai pembelian (`price`) adalah sekitar **120.65** dengan standar deviasi **183.63**, menunjukkan variasi yang cukup besar dalam harga produk.
#    - Nilai minimum untuk `price` adalah **0.85** dan maksimum **6735.00**, yang mungkin memerlukan pemeriksaan lebih lanjut untuk outlier.
#
# Langkah-Langkah Pembersihan Data:
# 1. **Menghapus Baris Duplikat**:
#    - Baris duplikat dapat dihapus untuk mencegah bias dalam analisis.
#
# 2. **Menangani Missing Values**:
#    - Nilai yang hilang di kolom **`order_approved_at`**, **`order_delivered_carrier_date`**, dan **`order_delivered_customer_date`** perlu diatasi. Pilihan:
#      - Jika jumlahnya relatif kecil (seperti `order_approved_at`), Anda bisa menghapus baris-baris tersebut.
#      - Untuk `order_delivered_customer_date` dan `order_delivered_carrier_date`, Anda mungkin ingin mengeksplorasi lebih lanjut untuk mengetahui apakah ini mencakup pesanan yang dibatalkan atau tidak pernah dikirim.
#
# 3. **Mengubah Tipe Data**:
#    - Kolom yang berkaitan dengan waktu (`order_approved_at`, `order_delivered_carrier_date`, `order_delivered_customer_date`) harus dikonversi menjadi **datetime** agar dapat dianalisis dengan benar.
#
# Berikut adalah kode untuk melakukan pembersihan data berdasarkan temuan di atas:
#
# Langkah Selanjutnya:
# - Setelah membersihkan data, kita bisa melanjutkan ke analisis RFM yang melibatkan penghitungan **Recency**, **Frequency**, dan **Monetary** untuk setiap pelanggan.
# - Apakah Anda ingin melanjutkan dengan langkah pembersihan data ini, atau ada langkah lain yang ingin dilakukan terlebih dahulu?

# %%
# Visualize missing values as a matrix
msno.matrix(rfm_df)
plt.show()

# %%
# Visualize missing values as a bar plot
msno.bar(rfm_df)
plt.show()

# %%
# Visualize missing values as a heatmap
msno.heatmap(rfm_df)
plt.show()

# %%
# Visualize missing values dendrogram
msno.dendrogram(rfm_df)
plt.show()

# %% [markdown]
# ### Cleaning Data

# %%
# Remove duplicate rows based on unique 'order_id'
rfm_df_unique = rfm_df.drop_duplicates(subset=['order_id'])

# Check the number of duplicates after removal
duplicate_rows_after = rfm_df_unique.duplicated(subset=['order_id']).sum()

# Display the cleaned dataframe info and the number of remaining duplicates
print("Number of duplicates after cleaning:", duplicate_rows_after)
rfm_df_unique.info()
# Out:
# Number of duplicates after cleaning: 0
# <class 'pandas.core.frame.DataFrame'>
# Index: 98666 entries, 0 to 112649
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       98666 non-null  object
#  1   customer_id                    98666 non-null  object
#  2   order_status                   98666 non-null  object
#  3   order_purchase_timestamp       98666 non-null  object
#  4   order_approved_at              98652 non-null  object
#  5   order_delivered_carrier_date   97657 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  98666 non-null  object
#  8   customer_unique_id             98666 non-null  object
#  9   customer_zip_code_prefix       98666 non-null  int64
#  10  customer_city                  98666 non-null  object
# ...

# %%
# Drop rows with missing values in key date columns
rfm_df_cleaned = rfm_df_unique.dropna(subset=['order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date'])

# Check if any missing values remain after the cleaning
missing_values_after_cleaning = rfm_df_cleaned.isnull().sum()

# Display the result
print("Missing values after cleaning:\n", missing_values_after_cleaning)
# Out:
# Missing values after cleaning:
#  order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# price                            0
# dtype: int64

# %%
# Convert relevant columns to datetime format
rfm_df_cleaned['order_purchase_timestamp'] = pd.to_datetime(rfm_df_cleaned['order_purchase_timestamp'])
rfm_df_cleaned['order_approved_at'] = pd.to_datetime(rfm_df_cleaned['order_approved_at'])
rfm_df_cleaned['order_delivered_carrier_date'] = pd.to_datetime(rfm_df_cleaned['order_delivered_carrier_date'])
rfm_df_cleaned['order_delivered_customer_date'] = pd.to_datetime(rfm_df_cleaned['order_delivered_customer_date'])

# Verify the conversion by checking the data types
converted_data_types = rfm_df_cleaned.dtypes

# Display the updated data types
print("Updated Data Types:\n", converted_data_types)
# Out:
# Updated Data Types:
#  order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date            object
# customer_unique_id                       object
# customer_zip_code_prefix                  int64
# customer_city                            object
# customer_state                           object
# price                                   float64
# dtype: object
# <ipython-input-7-ede7cb637569>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - Conclution pertanyaan 2
